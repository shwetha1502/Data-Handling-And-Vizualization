# %% [markdown]
# <a href="https://colab.research.google.com/github/shwetha1502/Data-Handling-And-Vizualization/blob/main/network_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import network as nx

# %%
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for network: filename=network-0.1-py3-none-any.whl size=3139 sha256=2b048b818e9a9231a55b86b76068cd046d38f5b167ad3ec57ace2e862202b19b
#   Stored in directory: /root/.cache/pip/wheels/25/97/b1/563d3a70ed8f588bf9cf448f079024a9751b54d15a0ce3d46b
# Successfully built network
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(2,3),(3,4),(5,1)])
pos=nx.spring_layout(G)
nx.draw(G,pos,with_labels=True, node_color='Skyblue', node_size=1400,edge_color='black', linewidths=1, font_size=15)
plt.show()
